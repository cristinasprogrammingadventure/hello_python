# %% [markdown]
# # Tasca S3 T01

# %%
import pandas as pd
import numpy as npy

# %% [markdown]
# ### Exercici 1

# %%
# EXERCICI 1
# Crea dues variables numèriques i fes operacions amb elles: suma els dos valors, resta, multiplica i divideix.

preu_kg_sindria=1.2
pes_kg_sindria1=8
pes_kg_sindria2=6

# %%
# multiplica
# dir quin es el preu de la sindria més grossa

preu_unitat_sindria=preu_kg_sindria*pes_kg_sindria1
print(preu_unitat_sindria)
# Out:
# 9.6

# %%
# multiplica
# dir quin es el preu de la sindria més petita

preu_unitat_sindria=preu_kg_sindria*pes_kg_sindria2
print(preu_unitat_sindria)
# Out:
# 7.199999999999999

# %%
# suma (el pes)

pes_sindries_1_2=(pes_kg_sindria1+pes_kg_sindria2)
pes_sindries_1_2
# Out:
# 14

# %%
# divideix
# dir quin es la proporció entre les dues sindries

proporcio=pes_kg_sindria2/pes_kg_sindria1

print(proporcio)
# Out:
# 0.75

# %%
# resta
# dir quin es la diferència de pes entre les dues sindries

diferencia = pes_kg_sindria1-pes_kg_sindria2
diferencia
# Out:
# 2

# %%
print("La diferència de pes entre les dues síndries és de ", pes_kg_sindria1-pes_kg_sindria2, "kilos")
# Out:
# La diferència de pes entre les dues síndries és de  2 kilos

# %% [markdown]
# ### Exercici 2

# %%
# Crea una variable amb el preu net d'un producte (preu_net). 
# Crea un altre variable amb l'IVA a aplicar sobre el producte (IVA). Mostra per pantalla els textos i valors següents:

preu_net_banyador=35.0
iva=0.21
iva_nominal="21"

preu_final=(preu_net_banyador*iva)+preu_net_banyador
preu_final

print("El preu net del producte és : ", preu_net_banyador, " €")
print("L'IVA aplicat al producte és: ", iva_nominal, " %") # altra opció : 
print("L'IVA aplicat al producte és: ", iva*100, " %")
print("El preu final de venda del producte és: ", preu_final, " €")
# Out:
# El preu net del producte és :  35.0  €
# L'IVA aplicat al producte és:  21  %
# L'IVA aplicat al producte és:  21.0  %
# El preu final de venda del producte és:  42.35  €
